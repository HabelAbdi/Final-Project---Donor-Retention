# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

donor_info = pd.read_csv('customer_churn.csv', low_memory=False)

# %%
import pandas as pd

# Rename columns
donor_info = donor_info.rename(columns={
    'Names': 'Customer_Name',
    'Total_Purchase': 'Total_Donation',
    'Account_Manager': 'Over_50k',
    'Years': 'Donation_Time',
    'Num_Sites': 'Education_Level',
    'Onboard_date': 'Onboard_Date',
    'Location': 'Customer_Location',
    'Company': 'Company_Name',
    'Churn': 'Churn'
})

donor_info


donor_info.to_csv('customer_churn.csv', index=False)

# %%
donor_info.shape
# Out:
# (900, 10)

# %%
#no null values
donor_info.isnull().sum()
# Out:
# Customer_Name        0
# Age                  0
# Total_Donation       0
# Over_50k             0
# Donation_Time        0
# Education_Level      0
# Onboard_Date         0
# Customer_Location    0
# Company_Name         0
# Churn                0
# dtype: int64

# %%
#checking for outlliers 

import matplotlib.pyplot as plt
import seaborn as sns

numerical_columns = donor_info.select_dtypes(include=['float64', 'int64']).columns

plt.figure(figsize=(12, 8))
for column in numerical_columns:
    sns.boxplot(x=donor_info[column])
    plt.title(f'Box Plot for {column}')
    plt.show()

# %%
outlier_rows = donor_info[outliers]
print(outlier_rows)
# Out:
#        Customer_Name   Age  Total_Donation  Over_50k  Donation_Time  \
# 10      Paula Harris  30.0        11575.37         1           5.22
# 26     Danielle Kirk  35.0        12403.81         0           4.42
# 145    Randall Weber  34.0        12983.26         1           6.53
# 175    William Haney  56.0        12502.81         0           5.47
# 251     Tiffany Case  42.0         7351.72         0           5.26
# 277  Whitney Beasley  42.0        12989.06         0           5.00
# 477  Joseph Anderson  48.0         8093.03         1           4.26
# 542       Aaron West  55.0        10056.55         0           4.98
# 860    Vanessa Myers  39.0        13731.45         1           8.15
#
#      Education_Level         Onboard_Date  \
# 10               8.0  2016-11-13 13:13:01
# 26              11.0  2007-07-31 06:39:54
# 145             13.0  2007-10-14 20:54:33
# 175              8.0  2007-08-09 17:54:53
# 251              9.0  2015-09-26 01:05:29
# ...

# %%
donor_info.hist(figsize=(20, 14))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Total_Donation'}>],
#        [<Axes: title={'center': 'Over_50k'}>,
#         <Axes: title={'center': 'Donation_Time'}>],
#        [<Axes: title={'center': 'Education_Level'}>,
#         <Axes: title={'center': 'Churn'}>]], dtype=object)

# %%
donor_info.head(5)
# Out:
#       Customer_Name   Age  Total_Donation  Over_50k  Donation_Time  \
# 0  Cameron Williams  42.0        11066.80         0           7.22
# 1     Kevin Mueller  41.0        11916.22         0           6.50
# 2       Eric Lozano  38.0        12884.75         0           6.67
# 3     Phillip White  42.0         8010.76         0           6.71
# 4    Cynthia Norton  37.0         9191.58         0           5.56
#
#    Education_Level         Onboard_Date  \
# 0              8.0  2013-08-30 07:00:40
# 1             11.0  2013-08-13 00:38:46
# 2             12.0  2016-06-29 06:20:07
# 3             10.0  2014-04-22 12:43:12
# 4              9.0  2016-01-19 15:31:15
#
#                                    Customer_Location  \
# 0      10265 Elizabeth Mission Barkerburgh, AK 89518
# 1  6157 Frank Gardens Suite 019 Carloshaven, RI 1...
# 2             1331 Keith Court Alyssahaven, DE 90114
# 3       13120 Daniel Mount Angelabury, WY 30645-4695
# ...

# %% [markdown]
# Checking columns to better understand the dataset

# %%
donor_info.describe()
# Out:
#               Age  Total_Donation    Over_50k  Donation_Time  Education_Level  \
# count  900.000000      900.000000  900.000000     900.000000       900.000000
# mean    41.816667    10062.824033    0.481111       5.273156         8.587778
# std      6.127560     2408.644532    0.499921       1.274449         1.764836
# min     22.000000      100.000000    0.000000       1.000000         3.000000
# 25%     38.000000     8497.122500    0.000000       4.450000         7.000000
# 50%     42.000000    10045.870000    0.000000       5.215000         8.000000
# 75%     46.000000    11760.105000    1.000000       6.110000        10.000000
# max     65.000000    18026.010000    1.000000       9.150000        14.000000
#
#             Churn
# count  900.000000
# mean     0.166667
# std      0.372885
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
sns.pairplot(donor_info, hue='Churn', diag_kind='kde')
plt.show()
# Out:
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
average_age = donor_info['Age'].mean()
print("Average Age:", average_age)
# Out:
# Average Age: 41.81666666666667

# %%
Average_Donation_Churned = donor_info[donor_info['Churn'] == 1]['Total_Donation'].mean()
Average_Donation_Not_Churned = donor_info[donor_info['Churn'] == 0]['Total_Donation'].mean()
print("Average Donation for Chruned:", Average_Donation_Churned)
print("Average Donation for Not Churned:", Average_Donation_Not_Churned)
# Out:
# Average Donation for Chruned: 10192.179933333333
# Average Donation for Not Churned: 10036.952853333334

# %%
avg_Education_level_Churned = donor_info[donor_info['Churn'] == 1]['Education_Level'].mean()
avg_Education_level_not_Churned = donor_info[donor_info['Churn'] == 0]['Education_Level'].mean()

print("Average Education level Churned:", avg_Education_level_Churned)
print("Average Education level not Churned:", avg_Education_level_not_Churned)
# Out:
# Average Education level Churned: 10.66
# Average Education level not Churned: 8.173333333333334

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 10))

for i, column in enumerate(donor_info.columns[:-1]):
    sns.histplot(data=donor_info, x=column, hue='Churn', kde=True, ax=axes[i//3, i%3])

plt.tight_layout()
plt.show()
# Out:
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Save the DataFrame to a CSV file
donor_info.to_csv('donor_churn.csv', index=False)
